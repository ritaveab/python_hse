# %% [markdown]
# <a href="https://colab.research.google.com/github/ritaveab/python_hse/blob/main/classroom_work_8_12_Baeva.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Синтаксис и основные операции

# %%
# 1

students = {
    "Иванов Иван": {
        "возраст": 20,
        "курс": 3,
        "специальность": "Информатика",
        "успеваемость": {
            "Математика": 4,
            "Программирование": 5,
            "Английский язык": 4
        }
    }
}

print("Созданный словарь студентов:")
print(students)

# 2

Иванов_Иван = dict(
        возраст = 20,
        курс = 3,
        специальность = "Информатика",
        успеваемость = dict(
            Математика = 4,
            Программирование = 5,
            Физика = 4,
            Английский_язык = 4
        )
    )

print("Созданный словарь студентов")
print(students)

# 3
students_data = [
    # Первый студент - каждый элемент это кортеж (ключ, значение)
    ("Иванов Алексей", [
        ("возраст", 20),
        ("курс", 3),
        ("специальность", "Информатика"),
        ("успеваемость", [
            ("Математика", 4.5),
            ("Программирование", 5.0),
            ("Физика", 4.0),
            ("Английский язык", 4.8)
        ])
    ])
    ]
# Out:
# Созданный словарь студентов:
# {'Иванов Иван': {'возраст': 20, 'курс': 3, 'специальность': 'Информатика', 'успеваемость': {'Математика': 4, 'Программирование': 5, 'Английский язык': 4}}}
# Созданный словарь студентов
# {'Иванов Иван': {'возраст': 20, 'курс': 3, 'специальность': 'Информатика', 'успеваемость': {'Математика': 4, 'Программирование': 5, 'Английский язык': 4}}}

# %%
# хороший вариант

users = {
    "alice2005": [20, "female", "London"],
    "rob_1": [43, "male", "Washington"],
    "m_kate": [33, "female", "Moscow"],
}

users = dict(
    alice2005=[20, "female", "London"],
    rob_1=[43, "male", "Washington"],
    m_kate=[33, "female", "Moscow"],
)

users = dict(
    [
        ("alice2005", [20, "female", "London"]),
        ("rob_1", [43, "male", "Washington"]),
        ("m_kate", [33, "female", "Moscow"]),
    ]
)
print("Users")
print(users)
# Out:
# Users
# {'alice2005': [20, 'female', 'London'], 'rob_1': [43, 'male', 'Washington'], 'm_kate': [33, 'female', 'Moscow']}

# %%
value1 = students["возраст"]
value2 = students.get("курс")
value3 = students.get("специальность", "N/A")

print(value1)
print(value2)
print(value3)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3281477593.py in <cell line: 0>()
# ----> 1 value1 = students["возраст"]
#       2 value2 = students.get("курс")
#       3 value3 = students.get("специальность", "N/A")
#       4
#       5 print(value1)
#
# KeyError: 'возраст'

# %%
value2 = students.get("курс")
value3 = students.get("специальность", "N/A")

print(value2)
print(value3)
# Out:
# None
# N/A

# %%
students_1 = students.pop("Иванов Иван")
del students["возраст"]

print(students_1)
print(students)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1134805876.py in <cell line: 0>()
# ----> 1 students_1 = students.pop("Иванов Иван")
#       2 del students["возраст"]
#       3
#       4 print(students_1)
#       5 print(students)
#
# KeyError: 'Иванов Иван'

# %%
import json

# Открытие
with open('data.json', 'r', encoding='utf-8') as f:
 config = json.load(f)

type(config) # dict

# Запись
with open('data_update.json', 'w', encoding='utf-8') as f:
 json.dump(config, f, ensure_ascii=False, indent=2)
