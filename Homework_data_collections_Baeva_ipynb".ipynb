# %% [markdown]
# <a href="https://colab.research.google.com/github/ritaveab/python_hse/blob/main/Homework_data_collections_Baeva_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Синтаксис

# %% [markdown]
# **Задача 1**
#
# Создайте список mixed_data, содержащий:
#
# - 3 числа (int)
# - 2 строки (str)
# - 1 вложенный список
# - 1 кортеж
# - 1 множество
#
# Добавьте в конец списка число 123
#
# Удалите вторую строку из списка
#
# Вставьте строку "inserted" на позицию 2
#
# Выведите итоговый список

# %%
mixed_data = [
    10,
    20,
    30,
    "text1",
    "text2",
    [4, 5, 6],
    ("a", "b"),
    {7, 8, 9}
]

mixed_data.append(123)

del mixed_data[4]

mixed_data.insert(2, "inserted")

print("Итоговый список:")
for i, item in enumerate(mixed_data):
    print(f"[{i}] {item} ({type(item).__name__})")
# Out:
# Итоговый список:
# [0] 10 (int)
# [1] 20 (int)
# [2] inserted (str)
# [3] 30 (int)
# [4] text1 (str)
# [5] [4, 5, 6] (list)
# [6] ('a', 'b') (tuple)
# [7] {8, 9, 7} (set)
# [8] 123 (int)

# %% [markdown]
# **Задача 2**
#
# Создайте кортеж user_credentials, содержащий:
#
# - Логин (строка)
#
# - Хэш пароля (строка)
#
# - Уровень доступа (целое число)
#
# Попробуйте изменить уровень доступа (должна возникнуть ошибка)
#
# Напишите комментарий, почему кортеж подходит для хранения таких данных

# %%
user_credentials = ("rita_b", "456asd4321dsa", 2)

print("Исходные учетные данные:")
print(f"Логин: {user_credentials[0]}")
print(f"Хэш пароля: {user_credentials[1]}")
print(f"Уровень доступа: {user_credentials[2]}")
print()
try:
    user_credentials[2] = 3
except TypeError as e:
    print(f"Ошибка при попытке изменения: {e}")
    print("Не позволяет изменять элементы после создания")
# Out:
# Исходные учетные данные:
# Логин: rita_b
# Хэш пароля: 456asd4321dsa
# Уровень доступа: 2
#
# Ошибка при попытке изменения: 'tuple' object does not support item assignment
# Не позволяет изменять элементы после создания

# %% [markdown]
# **Задача 3**
#
# Дано:

# %%
tags1 = {"python", "ml", "data"}
tags2 = {"ml", "nlp", "deeplearning"}

# %% [markdown]
# Найдите:
#
# - Общие теги (пересечение)
#
# - Все уникальные теги (объединение)
#
# - Теги, которые есть в tags1, но нет в tags2

# %%
tags1 = {"python", "ml", "data"}
tags2 = {"ml", "nlp", "deeplearning"}

# Общие теги (пересечение)
common_tags = tags1 & tags2
print("Общие теги (пересечение):", common_tags)

# Все уникальные теги (объединение)
all_unique_tags = tags1 | tags2
print("Все уникальные теги (объединение):", all_unique_tags)

# Теги, которые есть в tags1, но нет в tags2
tags_only_in_1 = tags1 - tags2
print("Теги только в tags1:", tags_only_in_1)
# Out:
# Общие теги (пересечение): {'ml'}
# Все уникальные теги (объединение): {'ml', 'nlp', 'data', 'python', 'deeplearning'}
# Теги только в tags1: {'data', 'python'}

# %% [markdown]
# ### Фильтрация и обработка текстовых данных

# %% [markdown]
# 1. Установите nltk и загрузите стоп-слова для русского и английского языков
#
# *Уже выполнено: просто запустите эту ячейку*

# %%
import nltk
import string
from nltk.corpus import stopwords

# Установка nltk и загрузка стоп-слов
nltk.download('stopwords')

# Загрузка стоп-слов для русского и английского языков
stopwords_english = stopwords.words('english')
stopwords_russian = stopwords.words('russian')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# 2. Конвертируйте списки слов на русском и английском, приведите их к виду множства `set`
#
# *Это стандартная операция: работа со стоп-словами всегда начинается с фильтрации, удаления дубликатов*

# %%
### ваш код здесь ###

# %% [markdown]
# 3. Выведите на экран первые 10 стоп-слов из двух списков
#
# *Подумайте, как это сделать, ведь `set` нельзя индексировать, а созданный список слов нельзя перезаписывать*

# %%
stopwords_english = stopwords.words('english')
stopwords_russian = stopwords.words('russian')

stopwords_english_set = set(stopwords_english)
stopwords_russian_set = set(stopwords_russian)

print("Английские стоп-слова (первые 10):", stopwords_english[:10])
print("Русские стоп-слова (первые 10):", stopwords_russian[:10])
# Out:
# Английские стоп-слова (первые 10): ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an']
# Русские стоп-слова (первые 10): ['и', 'в', 'во', 'не', 'что', 'он', 'на', 'я', 'с', 'со']

# %% [markdown]
# 4. Дан текст

# %%
# Исходный текст
text = """
This is a sample text for processing. It contains some stopwords and important words.
Этот текст содержит как английские, так и русские слова, включая стоп-слова.
"""

# %% [markdown]
# Допишите функцию в указанном плейсхолдере
#
# Функция:
#
# - удаляет знаки препинания
# - разбивает текст на слова
# - приводит текст к нижнему регистру

# %% [markdown]
# Применим нашу функцию к тексту

# %%
# Токенизируем текст
words = tokenize_text(text)

# %% [markdown]
# Выведите на экран список токенов и общее количество слов

# %%
import string

# Исходный текст
text = """
This is a sample text for processing. It contains some stopwords and important words.
Этот текст содержит как английские, так и русские слова, включая стоп-слова.
"""

# Токенизация текста на слова
def tokenize_text(text):
    # Убираем знаки препинания и разбиваем на слова
    # Создаем таблицу перевода для удаления знаков препинания
    translator = str.maketrans('', '', string.punctuation)
    # Удаляем пунктуацию и приводим к нижнему регистру
    clean_text = text.translate(translator).lower()
    # Разбиваем на слова
    words = clean_text.split()
    return words

# Тестируем функцию
tokenized_words = tokenize_text(text)
print("Токенизированные слова:")
print(tokenized_words)
print(f"\nКоличество слов: {len(tokenized_words)}")
# Out:
# Все слова после токенизации: ['this', 'is', 'a', 'sample', 'text', 'for', 'processing', 'it', 'contains', 'some', 'stopwords', 'and', 'important', 'words', 'этот', 'текст', 'содержит', 'как', 'английские', 'так', 'и', 'русские', 'слова', 'включая', 'стопслова']
# Всего слов: 25

# %% [markdown]
# 5. Произведите фильтрацию стоп-слов для двух языков
#
# - Создайте пустой список
# - Запустите цикл for (`for word in words`, для каждого слова в списке слов)
# - Если слова нет в списке стоп-слов
# - Сделайте `append` в созданный список
#
# *Допишите функцию*

# %%
# Фильтрация стоп-слов для обоих языков
def filter_stopwords(words, stopwords_set):
    filtered_words = []
    for word in words:
        if word not in stopwords_set:
            filtered_words.append(word)
    return filtered_words

# %% [markdown]
# 6. Примените операции со множествами

# %%
# Объедините стоп-слова обоих языков в общее множество
combined_stopwords = stopwords_english_set | stopwords_russian_set

# %% [markdown]
# 7. Применим нашу функцию для фильтрации данных
#
# *В переменной `all_stopwords` должен быть результат объединения множеств из пункта 6*

# %%
# Фильтруем стоп-слова
meaningful_words = filter_stopwords(words, all_stopwords)

# %% [markdown]
# Выведите на экран список `meaningful_words`, а также длину этого списка

# %%
filtered_text = filter_stopwords(tokenized_words, combined_stopwords)

print("Исходные слова:", tokenized_words)
print("После фильтрации стоп-слов:", filtered_text)
print(f"Осталось после фильтрации: {len(filtered_text)}")
# Out:
# Исходные слова: ['this', 'is', 'a', 'sample', 'text', 'for', 'processing', 'it', 'contains', 'some', 'stopwords', 'and', 'important', 'words', 'этот', 'текст', 'содержит', 'как', 'английские', 'так', 'и', 'русские', 'слова', 'включая', 'стопслова']
# После фильтрации стоп-слов: ['sample', 'text', 'processing', 'contains', 'stopwords', 'important', 'words', 'текст', 'содержит', 'английские', 'русские', 'слова', 'включая', 'стопслова']
# Осталось после фильтрации: 14

# %% [markdown]
# 8. Создаем множество уникальных значимых слов
#
# *Конвертируем список `meaningful_words` к виду множества*

# %%
all_stopwords = combined_stopwords

meaningful_words = filter_stopwords(tokenized_words, all_stopwords)

# %% [markdown]
# Выведите на экран результат, а также длину полчившегося множества

# %%
all_stopwords = combined_stopwords

meaningful_words = filter_stopwords(tokenized_words, all_stopwords)
unique_meaningful_words = set(meaningful_words)

print("Уникальные значимые слова:", unique_meaningful_words)
print("Количество уникальных значимых слов:", len(unique_meaningful_words))
# Out:
# Уникальные значимые слова: {'processing', 'русские', 'включая', 'текст', 'слова', 'words', 'stopwords', 'contains', 'sample', 'стопслова', 'text', 'содержит', 'important', 'английские'}
# Количество уникальных значимых слов: 14

# %% [markdown]
# 9. Создайте отчет
#
# - выведите исходное количество стоп-слов на английском
# - исходное количество слов на русском
# - общее количество стоп-слов

# %%
print(f"Всего стоп-слов (английские): {len(stopwords_english)}")
print(f"Всего стоп-слов (русские): {len(stopwords_russian)}")
print(f"Всего стоп-слов (объединенные): {len(combined_stopwords)}")
# Out:
# Всего стоп-слов (английские): 198
# Всего стоп-слов (русские): 151
# Всего стоп-слов (объединенные): 349

# %% [markdown]
# 10. Проведите анализ результатов: какие стоп-слова были удалены из исходного текста?
#
# - создайте список для сохранения отфильтрованных слов
# - для каждого слова исходного текста (`text`)
# - если данное слово было в списке стоп-слов
# - добавляем его в созданный список
#
# *Выведите на экран отфильтрованные слова (т.е. удаленные)*

# %%
removed_stopwords = []

for word in tokenized_words:
    if word in all_stopwords:
        removed_stopwords.append(word)

print("Отфильтрованные стоп-слова:", removed_stopwords)
# Out:
# Отфильтрованные стоп-слова: ['this', 'is', 'a', 'for', 'it', 'some', 'and', 'этот', 'как', 'так', 'и']
