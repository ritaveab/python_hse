# %% [markdown]
# <a href="https://colab.research.google.com/github/ritaveab/python_hse/blob/main/Baeva_homework_data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Задание 1: выгрузка файлов

# %% [markdown]
# 1. Зайдите в репозиторий датасетов для обучения диалоговых систем
# 2. Найдите все файлы с расширением *.txt (их всего 5 в репозитории)
# 3. Выгрузите каждый файл с помощью утилиты `wget`
# - Для этого откройте датасет в браузере, например, https://github.com/Phylliida/Dialogue-Datasets/blob/master/TwitterLowerAsciiCorpus.txt
# - Затем найдите кнопку `raw`, которая откроет вам файл "как есть" (как в блокноте!)
# - Скопируйте ссылку на файл (она выглядит так: https://raw.githubusercontent.com/Phylliida/Dialogue-Datasets/refs/heads/master/TwitterLowerAsciiCorpus.txt)
# - Воспользуйтесь `wget`
# ---
# Как использовать `wget`:
# ---

# %%
# !wget https://raw.githubusercontent.com/Phylliida/Dialogue-Datasets/refs/heads/master/TwitterLowerAsciiCorpus.txt -O twitter.txt
# Out:
# --2025-11-27 11:10:00--  https://raw.githubusercontent.com/Phylliida/Dialogue-Datasets/refs/heads/master/TwitterLowerAsciiCorpus.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 593707 (580K) [text/plain]
# Saving to: ‘twitter.txt’
#
# twitter.txt         100%[===================>] 579.79K  --.-KB/s    in 0.04s
#
# 2025-11-27 11:10:00 (13.4 MB/s) - ‘twitter.txt’ saved [593707/593707]

# %% [markdown]
# Здесь:
# - ! указывает на то, что это консольная утилита, а не код на python
# - после wget идет полный адрес ссылки для скачивания файла
# - после параметра `-O` указываем название файла, под которым мы хотим скачать файл

# %%
# Ваш код здесь: повторите процедуру для остальных файлов (всего должно быть 5 файлов)

# 1
# !wget https://raw.githubusercontent.com/Phylliida/Dialogue-Datasets/refs/heads/master/TwitterLowerAsciiCorpus.txt -O TwitterLowerAsciiCorpus.txt

# 2
# !wget https://raw.githubusercontent.com/Phylliida/Dialogue-Datasets/refs/heads/master/TwitterConvCorpus.txt -O TwitterConvCorpus.txt

# 3
# !wget https://raw.githubusercontent.com/Phylliida/Dialogue-Datasets/refs/heads/master/MovieCorpus.txt -O MovieCorpus.txt

# 4
# !wget https://raw.githubusercontent.com/Phylliida/Dialogue-Datasets/refs/heads/master/BNCSplitWordsCorpus.txt -O BNCSplitWordsCorpus.txt

# 5
# !wget https://raw.githubusercontent.com/Phylliida/Dialogue-Datasets/refs/heads/master/BNCCorpus.txt -O BNCCorpus.txt
# Out:
# --2025-12-06 00:40:08--  https://raw.githubusercontent.com/Phylliida/Dialogue-Datasets/refs/heads/master/TwitterLowerAsciiCorpus.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 593707 (580K) [text/plain]
# Saving to: ‘TwitterLowerAsciiCorpus.txt’
#
# TwitterLowerAsciiCo 100%[===================>] 579.79K  --.-KB/s    in 0.06s
#
# 2025-12-06 00:40:09 (8.74 MB/s) - ‘TwitterLowerAsciiCorpus.txt’ saved [593707/593707]
#
# --2025-12-06 00:40:09--  https://raw.githubusercontent.com/Phylliida/Dialogue-Datasets/refs/heads/master/TwitterConvCorpus.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 612338 (598K) [text/plain]
# Saving to: ‘TwitterConvCorpus.txt’
#
# TwitterConvCorpus.t 100%[===================>] 597.99K  --.-KB/s    in 0.06s
#
# 2025-12-06 00:40:09 (9.66 MB/s) - ‘TwitterConvCorpus.txt’ saved [612338/612338]
#
# --2025-12-06 00:40:09--  https://raw.githubusercontent.com/Phylliida/Dialogue-Datasets/refs/heads/master/MovieCorpus.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 16976724 (16M) [text/plain]
# Saving to: ‘MovieCorpus.txt’
#
# MovieCorpus.txt     100%[===================>]  16.19M   100MB/s    in 0.2s
#
# 2025-12-06 00:40:10 (100 MB/s) - ‘MovieCorpus.txt’ saved [16976724/16976724]
#
# --2025-12-06 00:40:10--  https://raw.githubusercontent.com/Phylliida/Dialogue-Datasets/refs/heads/master/BNCSplitWordsCorpus.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 19173003 (18M) [text/plain]
# Saving to: ‘BNCSplitWordsCorpus.txt’
#
# BNCSplitWordsCorpus 100%[===================>]  18.28M  93.6MB/s    in 0.2s
#
# 2025-12-06 00:40:12 (93.6 MB/s) - ‘BNCSplitWordsCorpus.txt’ saved [19173003/19173003]
#
# --2025-12-06 00:40:12--  https://raw.githubusercontent.com/Phylliida/Dialogue-Datasets/refs/heads/master/BNCCorpus.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 19081694 (18M) [text/plain]
# Saving to: ‘BNCCorpus.txt’
#
# BNCCorpus.txt       100%[===================>]  18.20M   110MB/s    in 0.2s
#
# 2025-12-06 00:40:13 (110 MB/s) - ‘BNCCorpus.txt’ saved [19081694/19081694]

# %% [markdown]
# ## Задание 2: открываем файлы

# %% [markdown]
# Изучите туториал по работе с файлами, который вы получили в чате. Каждый файл нужно теперь открыть, а его содержание - записать в переменную *любым удобным вам способом*
#
# Пример:

# %%
# Открываем файл с указанием кодировки
file = open('twitter.txt', 'r', encoding='utf-8')
dataset_content = file.read()
file.close()

print("Файл успешно загружен!")
print(f"Размер файла: {len(dataset_content)} символов")
dataset_content[:100]
# Out:
# Файл успешно загружен!
# Размер файла: 593707 символов
# "what's up dadyo when did you get back on twitter? haha\nlike 2 weeks ago and it's going as terribly a"

# %%
# Ваш код здесь: откройте все файлы, выведите на экран их размер и первые 100 символов (всего должно быть обработано 5 файлов)

# %%
# Открываем файл с указанием кодировки
file = open('TwitterLowerAsciiCorpus.txt', 'r', encoding='utf-8')
dataset_content = file.read()
file.close()

print("Файл успешно загружен!")
print(f"Размер файла: {len(dataset_content)} символов")
dataset_content[:100]
# Out:
# Файл успешно загружен!
# Размер файла: 593707 символов
# "what's up dadyo when did you get back on twitter? haha\nlike 2 weeks ago and it's going as terribly a"

# %%
# Открываем файл с указанием кодировки
file = open('TwitterConvCorpus.txt', 'r', encoding='utf-8')
dataset_content = file.read()
file.close()

print("Файл успешно загружен!")
print(f"Размер файла: {len(dataset_content)} символов")
dataset_content[:100]
# Out:
# Файл успешно загружен!
# Размер файла: 598556 символов
# "what's up dadyo when did you get back on Twitter? Haha\nlike 2 weeks ago and it's going as terribly a"

# %%
# Открываем файл с указанием кодировки
file = open('MovieCorpus.txt', 'r', encoding='utf-8')
dataset_content = file.read()
file.close()

print("Файл успешно загружен!")
print(f"Размер файла: {len(dataset_content)} символов")
dataset_content[:100]
# Out:
# Файл успешно загружен!
# Размер файла: 16976724 символов
# "Colonel Durnford... William Vereker. I hear you 've been seeking Officers?\nGood ones, yes, Mr Vereke"

# %%
# Открываем файл с указанием кодировки
file = open('BNCSplitWordsCorpus.txt', 'r', encoding='utf-8')
dataset_content = file.read()
file.close()

print("Файл успешно загружен!")
print(f"Размер файла: {len(dataset_content)} символов")
dataset_content[:100]
# Out:
# Файл успешно загружен!
# Размер файла: 19173003 символов
# 'You enjoyed yourself in America\nEh\ndid you\nOh I covered a nice trip yes\nOh very good\nsaw Mary and An'

# %%
# Открываем файл с указанием кодировки
file = open('BNCCorpus.txt', 'r', encoding='utf-8')
dataset_content = file.read()
file.close()

print("Файл успешно загружен!")
print(f"Размер файла: {len(dataset_content)} символов")
dataset_content[:100]
# Out:
# Файл успешно загружен!
# Размер файла: 19081694 символов
# 'You enjoyed yourself in America\nEh\ndid you\nOh I covered a nice tripyes\nOh very good\nsaw Mary and And'

# %% [markdown]
# ## Задание 3: первичный анализ

# %% [markdown]
# Выведем статистику для каждого файла по образцу:

# %%
# 1. Разбиваем содержание файла на строки
# Ваш код здесь
with open("TwitterLowerAsciiCorpus.txt", "r", encoding="utf-8") as file:
  all_lines = file.readlines()

# 2. Считаем статистику (используйте цикл for и вот такие счетчики >)
total_lines = 0         # общее количество строк
total_words = 0         # общее количество слов
total_chars = 0         # общее количество символов
non_empty_lines = 0     # количество непустых строк (длина такой строки больше 0)

# Ваш код здесь: реализуйте логику для получения таких статистик
for line in all_lines:
    total_lines += 1
    clean_line = line.rstrip("\n")

    total_chars += len(clean_line)
    words = clean_line.split()
    total_words += len(words)

    if len(clean_line) > 0:
        non_empty_lines += 1

# 3. Анализ длин строк
max_line_length = 0   #  максимальная длина строки
min_line_length = None   # минимальная длина строки

# Ваш код здесь: реализуйте логику для получения таких статистик
for line in all_lines:
    clean_line = line.rstrip("\n")
    length = len(clean_line)

    # обновляем максимум
    if length > max_line_length:
        max_line_length = length

    # обновляем минимум
    if min_line_length is None or length < min_line_length:
        min_line_length = length

# Выводим результат на экран для каждого файла в таком формате:
print(f"Всего строк: {total_lines}")
print(f"Непустых строк: {non_empty_lines}")
print(f"Всего слов: {total_words}")
print(f"Всего символов: {total_chars}")
print(f"Макс. длина строки: {max_line_length}")
print(f"Мин. длина строки: {min_line_length}")
# Out:
# Всего строк: 16556
# Непустых строк: 10514
# Всего слов: 112977
# Всего символов: 577151
# Макс. длина строки: 146
# Мин. длина строки: 0

# %%
# 1. Разбиваем содержание файла на строки
# Ваш код здесь
with open("TwitterConvCorpus.txt", "r", encoding="utf-8") as file:
  all_lines = file.readlines()

# 2. Считаем статистику (используйте цикл for и вот такие счетчики >)
total_lines = 0         # общее количество строк
total_words = 0         # общее количество слов
total_chars = 0         # общее количество символов
non_empty_lines = 0     # количество непустых строк (длина такой строки больше 0)

# Ваш код здесь: реализуйте логику для получения таких статистик
for line in all_lines:
    total_lines += 1
    clean_line = line.rstrip("\n")

    total_chars += len(clean_line)
    words = clean_line.split()
    total_words += len(words)

    if len(clean_line) > 0:
        non_empty_lines += 1

# 3. Анализ длин строк
max_line_length = 0   #  максимальная длина строки
min_line_length = None   # минимальная длина строки

# Ваш код здесь: реализуйте логику для получения таких статистик
for line in all_lines:
    clean_line = line.rstrip("\n")
    length = len(clean_line)

    # обновляем максимум
    if length > max_line_length:
        max_line_length = length

    # обновляем минимум
    if min_line_length is None or length < min_line_length:
        min_line_length = length

# Выводим результат на экран для каждого файла в таком формате:
print(f"Всего строк: {total_lines}")
print(f"Непустых строк: {non_empty_lines}")
print(f"Всего слов: {total_words}")
print(f"Всего символов: {total_chars}")
print(f"Макс. длина строки: {max_line_length}")
print(f"Мин. длина строки: {min_line_length}")
# Out:
# Всего строк: 16556
# Непустых строк: 10628
# Всего слов: 114910
# Всего символов: 582000
# Макс. длина строки: 146
# Мин. длина строки: 0

# %%
# 1. Разбиваем содержание файла на строки
# Ваш код здесь
with open("MovieCorpus.txt", "r", encoding="utf-8") as file:
  all_lines = file.readlines()

# 2. Считаем статистику (используйте цикл for и вот такие счетчики >)
total_lines = 0         # общее количество строк
total_words = 0         # общее количество слов
total_chars = 0         # общее количество символов
non_empty_lines = 0     # количество непустых строк (длина такой строки больше 0)

# Ваш код здесь: реализуйте логику для получения таких статистик
for line in all_lines:
    total_lines += 1
    clean_line = line.rstrip("\n")

    total_chars += len(clean_line)
    words = clean_line.split()
    total_words += len(words)

    if len(clean_line) > 0:
        non_empty_lines += 1

# 3. Анализ длин строк
max_line_length = 0   #  максимальная длина строки
min_line_length = None   # минимальная длина строки

# Ваш код здесь: реализуйте логику для получения таких статистик
for line in all_lines:
    clean_line = line.rstrip("\n")
    length = len(clean_line)

    # обновляем максимум
    if length > max_line_length:
        max_line_length = length

    # обновляем минимум
    if min_line_length is None or length < min_line_length:
        min_line_length = length

# Выводим результат на экран для каждого файла в таком формате:
print(f"Всего строк: {total_lines}")
print(f"Непустых строк: {non_empty_lines}")
print(f"Всего слов: {total_words}")
print(f"Всего символов: {total_chars}")
print(f"Макс. длина строки: {max_line_length}")
print(f"Мин. длина строки: {min_line_length}")
# Out:
# Всего строк: 304713
# Непустых строк: 304713
# Всего слов: 3185395
# Всего символов: 16672011
# Макс. длина строки: 3039
# Мин. длина строки: 1

# %%
# 1. Разбиваем содержание файла на строки
# Ваш код здесь
with open("BNCSplitWordsCorpus.txt", "r", encoding="utf-8") as file:
  all_lines = file.readlines()

# 2. Считаем статистику (используйте цикл for и вот такие счетчики >)
total_lines = 0         # общее количество строк
total_words = 0         # общее количество слов
total_chars = 0         # общее количество символов
non_empty_lines = 0     # количество непустых строк (длина такой строки больше 0)

# Ваш код здесь: реализуйте логику для получения таких статистик
for line in all_lines:
    total_lines += 1
    clean_line = line.rstrip("\n")

    total_chars += len(clean_line)
    words = clean_line.split()
    total_words += len(words)

    if len(clean_line) > 0:
        non_empty_lines += 1

# 3. Анализ длин строк
max_line_length = 0   #  максимальная длина строки
min_line_length = None   # минимальная длина строки

# Ваш код здесь: реализуйте логику для получения таких статистик
for line in all_lines:
    clean_line = line.rstrip("\n")
    length = len(clean_line)

    # обновляем максимум
    if length > max_line_length:
        max_line_length = length

    # обновляем минимум
    if min_line_length is None or length < min_line_length:
        min_line_length = length

# Выводим результат на экран для каждого файла в таком формате:
print(f"Всего строк: {total_lines}")
print(f"Непустых строк: {non_empty_lines}")
print(f"Всего слов: {total_words}")
print(f"Всего символов: {total_chars}")
print(f"Макс. длина строки: {max_line_length}")
print(f"Мин. длина строки: {min_line_length}")
# Out:
# Всего строк: 611014
# Непустых строк: 606486
# Всего слов: 4052241
# Всего символов: 18561989
# Макс. длина строки: 2773
# Мин. длина строки: 0

# %%
# 1. Разбиваем содержание файла на строки
# Ваш код здесь
with open("BNCCorpus.txt", "r", encoding="utf-8") as file:
  all_lines = file.readlines()

# 2. Считаем статистику (используйте цикл for и вот такие счетчики >)
total_lines = 0         # общее количество строк
total_words = 0         # общее количество слов
total_chars = 0         # общее количество символов
non_empty_lines = 0     # количество непустых строк (длина такой строки больше 0)

# Ваш код здесь: реализуйте логику для получения таких статистик
for line in all_lines:
    total_lines += 1
    clean_line = line.rstrip("\n")

    total_chars += len(clean_line)
    words = clean_line.split()
    total_words += len(words)

    if len(clean_line) > 0:
        non_empty_lines += 1

# 3. Анализ длин строк
max_line_length = 0   #  максимальная длина строки
min_line_length = None   # минимальная длина строки

# Ваш код здесь: реализуйте логику для получения таких статистик
for line in all_lines:
    clean_line = line.rstrip("\n")
    length = len(clean_line)

    # обновляем максимум
    if length > max_line_length:
        max_line_length = length

    # обновляем минимум
    if min_line_length is None or length < min_line_length:
        min_line_length = length

# Выводим результат на экран для каждого файла в таком формате:
print(f"Всего строк: {total_lines}")
print(f"Непустых строк: {non_empty_lines}")
print(f"Всего слов: {total_words}")
print(f"Всего символов: {total_chars}")
print(f"Макс. длина строки: {max_line_length}")
print(f"Мин. длина строки: {min_line_length}")
# Out:
# Всего строк: 611014
# Непустых строк: 606486
# Всего слов: 3719853
# Всего символов: 18470680
# Макс. длина строки: 2702
# Мин. длина строки: 0

# %% [markdown]
# ## Задание 4: чистка текста

# %%
import re

cleaned_lines = [] # чистим текст построчно (сохраняем каждую очищенную строку в список)
all_cleaned_words = [] # также сохраняем все слова после очистки в список

# Ваш код здесь: реализуйте очистку с помощью цикла for и RegEx
# 1. Используйте strip для удаления лишних пробелов из строки
# 2. Очищаем строку: оставляем только буквы, цифры и пробелы
# 3. Убираем лишние пробелы
# 4. Приводим к нижнему регистру
# 5. Собираем все слова после очистки в единый список
#    - не фиксируем слова короче 1 символа

# Выводим результат для каждого текста по образцу
print(f"Пример очищенной строки: {cleaned_lines[0][:100]}...")
print(f"Всего очищенных слов: {len(all_cleaned_words)}")
# Out:
# Пример очищенной строки: what s up dadyo when did you get back on twitter haha...
# Всего очищенных слов: 104967

# %%
import re
cleaned_lines1 = []
all_cleaned_words1 = []
with open('TwitterLowerAsciiCorpus.txt', 'r', encoding='utf-8') as file:
    for line in file:
# 1. Используйте strip для удаления лишних пробелов из строки
     line = line.strip()
# 2. Очищаем строку: оставляем только буквы, цифры и пробелы
     line = re.sub(r'[^a-zA-Zа-яА-Я0-9\s]', '', line)
# 3. Убираем лишние пробелы
     line = re.sub(r'\s+', ' ', line)
# 4. Приводим к нижнему регистру
     line = line.lower()
# 5. Собираем все слова после очистки в единый список
#    - не фиксируем слова короче 1 символа
     if line:
            cleaned_lines1.append(line)
            words = line.split()
            for word in words:
                if len(word) > 1:
                    all_cleaned_words1.append(word)
# Выводим результат для каждого текста по образцу
print(f"Пример очищенной строки: {cleaned_lines1[0][:100]}...")
print(f"Всего очищенных слов: {len(all_cleaned_words1)}")
# Out:
# Пример очищенной строки: whats up dadyo when did you get back on twitter haha...
# Всего очищенных слов: 104907

# %%
import re
cleaned_lines2 = []
all_cleaned_words2 = []
with open('TwitterConvCorpus.txt', 'r', encoding='utf-8') as file:
    for line in file:
# 1. Используйте strip для удаления лишних пробелов из строки
     line = line.strip()
# 2. Очищаем строку: оставляем только буквы, цифры и пробелы
     line = re.sub(r'[^a-zA-Zа-яА-Я0-9\s]', '', line)
# 3. Убираем лишние пробелы
     line = re.sub(r'\s+', ' ', line)
# 4. Приводим к нижнему регистру
     line = line.lower()
# 5. Собираем все слова после очистки в единый список
#    - не фиксируем слова короче 1 символа
     if line:
            cleaned_lines2.append(line)
            words = line.split()
            for word in words:
                if len(word) > 1:
                    all_cleaned_words2.append(word)
# Выводим результат для каждого текста по образцу
print(f"Пример очищенной строки: {cleaned_lines2[0][:100]}...")
print(f"Всего очищенных слов: {len(all_cleaned_words2)}")
# Out:
# Пример очищенной строки: whats up dadyo when did you get back on twitter haha...
# Всего очищенных слов: 104910

# %%
import re
cleaned_lines3 = []
all_cleaned_words3 = []
with open('MovieCorpus.txt', 'r', encoding='utf-8') as file:
    for line in file:
# 1. Используйте strip для удаления лишних пробелов из строки
     line = line.strip()
# 2. Очищаем строку: оставляем только буквы, цифры и пробелы
     line = re.sub(r'[^a-zA-Zа-яА-Я0-9\s]', '', line)
# 3. Убираем лишние пробелы
     line = re.sub(r'\s+', ' ', line)
# 4. Приводим к нижнему регистру
     line = line.lower()
# 5. Собираем все слова после очистки в единый список
#    - не фиксируем слова короче 1 символа
     if line:
            cleaned_lines3.append(line)
            words = line.split()
            for word in words:
                if len(word) > 1:
                    all_cleaned_words3.append(word)
# Выводим результат для каждого текста по образцу
print(f"Пример очищенной строки: {cleaned_lines3[0][:100]}...")
print(f"Всего очищенных слов: {len(all_cleaned_words3)}")
# Out:
# Пример очищенной строки: colonel durnford william vereker i hear you ve been seeking officers...
# Всего очищенных слов: 3001928

# %%
import re
cleaned_lines4 = []
all_cleaned_words4 = []
with open('BNCSplitWordsCorpus.txt', 'r', encoding='utf-8') as file:
    for line in file:
# 1. Используйте strip для удаления лишних пробелов из строки
     line = line.strip()
# 2. Очищаем строку: оставляем только буквы, цифры и пробелы
     line = re.sub(r'[^a-zA-Zа-яА-Я0-9\s]', '', line)
# 3. Убираем лишние пробелы
     line = re.sub(r'\s+', ' ', line)
# 4. Приводим к нижнему регистру
     line = line.lower()
# 5. Собираем все слова после очистки в единый список
#    - не фиксируем слова короче 1 символа
     if line:
            cleaned_lines4.append(line)
            words = line.split()
            for word in words:
                if len(word) > 1:
                    all_cleaned_words4.append(word)
# Выводим результат для каждого текста по образцу
print(f"Пример очищенной строки: {cleaned_lines4[0][:100]}...")
print(f"Всего очищенных слов: {len(all_cleaned_words4)}")
# Out:
# Пример очищенной строки: you enjoyed yourself in america...
# Всего очищенных слов: 3754297

# %%
import re
cleaned_lines5 = []
all_cleaned_words5 = []
with open('BNCCorpus.txt', 'r', encoding='utf-8') as file:
    for line in file:
# 1. Используйте strip для удаления лишних пробелов из строки
     line = line.strip()
# 2. Очищаем строку: оставляем только буквы, цифры и пробелы
     line = re.sub(r'[^a-zA-Zа-яА-Я0-9\s]', '', line)
# 3. Убираем лишние пробелы
     line = re.sub(r'\s+', ' ', line)
# 4. Приводим к нижнему регистру
     line = line.lower()
# 5. Собираем все слова после очистки в единый список
#    - не фиксируем слова короче 1 символа
     if line:
            cleaned_lines5.append(line)
            words = line.split()
            for word in words:
                if len(word) > 1:
                    all_cleaned_words5.append(word)
# Выводим результат для каждого текста по образцу
print(f"Пример очищенной строки: {cleaned_lines5[0][:100]}...")
print(f"Всего очищенных слов: {len(all_cleaned_words5)}")
# Out:
# Пример очищенной строки: you enjoyed yourself in america...
# Всего очищенных слов: 3524835

# %% [markdown]
# ## Задание 5: статистика

# %% [markdown]
# Часть 1: получаем статистику распределений длин слов

# %%
# Статистика по очищенным данным
total_words = len(all_cleaned_words)
total_chars = 0
word_lengths = []

# Ваш код здесь: создайте список длин слов word_lengths
#                и посчитайте общее количество символов total_chars

# Анализ длин слов: допишите код для подсчета количества слов разной длины
word_length_count = {}
# Ваш код здесь: для каждого значения длины в списке word_lengths
#                если длина уже зафиксирована в word_length_count, то выполняем >
        word_length_count[length] += 1
#                иначе: выполняем >
        word_length_count[length] = 1

# Ожидаемый результат:
print(f"Слов после очистки: {total_words_after}")
print(f"Символов после очистки: {total_chars_after}")
print("Распределение длин слов:")
for length in sorted(word_length_count.keys()):
    print(f"  {length} букв: {word_length_count[length]} слов")
# Out:
# Слов после очистки: 104967
# Символов после очистки: 438282
# Распределение длин слов:
#   2 букв: 20430 слов
#   3 букв: 25349 слов
#   4 букв: 25124 слов
#   5 букв: 12802 слов
#   6 букв: 7759 слов
#   7 букв: 6005 слов
#   8 букв: 3435 слов
#   9 букв: 2024 слов
#   10 букв: 1063 слов
#   11 букв: 491 слов
#   12 букв: 238 слов
#   13 букв: 118 слов
#   14 букв: 51 слов
#   15 букв: 26 слов
#   16 букв: 17 слов
#   17 букв: 10 слов
#   18 букв: 5 слов
#   19 букв: 5 слов
#   20 букв: 5 слов
#   21 букв: 1 слов
#   22 букв: 2 слов
#   23 букв: 2 слов
#   24 букв: 1 слов
#   25 букв: 1 слов
#   33 букв: 1 слов
#   41 букв: 1 слов
#   98 букв: 1 слов

# %%
# Статистика по очищенным данным
total_words1 = len(all_cleaned_words1)
total_chars1 = 0
word_lengths1 = []

# Ваш код здесь: создайте список длин слов word_lengths
# и посчитайте общее количество символов total_chars

for word in all_cleaned_words1:
    length = len(word)
    word_lengths1.append(length)
    total_chars1 += length

# Анализ длин слов: допишите код для подсчета количества слов разной длины
word_length_count1 = {}
for length in word_lengths1:
# Ваш код здесь: для каждого значения длины в списке word_lengths
# если длина уже зафиксирована в word_length_count, то выполняем >
    if length in word_length_count1:
        word_length_count1[length] += 1
#                иначе: выполняем >
    else:
        word_length_count1[length] = 1

total_words_after = total_words1
total_chars_after = total_chars1

# Ожидаемый результат:
print(f"Слов после очистки: {total_words_after}")
print(f"Символов после очистки: {total_chars_after}")
print("Распределение длин слов:")
for length in sorted(word_length_count1.keys()):
    print(f"  {length} букв: {word_length_count1[length]} слов")
# Out:
# Слов после очистки: 104907
# Символов после очистки: 443771
# Распределение длин слов:
#   2 букв: 19606 слов
#   3 букв: 24775 слов
#   4 букв: 25465 слов
#   5 букв: 13273 слов
#   6 букв: 7902 слов
#   7 букв: 6084 слов
#   8 букв: 3465 слов
#   9 букв: 2053 слов
#   10 букв: 1115 слов
#   11 букв: 540 слов
#   12 букв: 272 слов
#   13 букв: 147 слов
#   14 букв: 75 слов
#   15 букв: 44 слов
#   16 букв: 27 слов
#   17 букв: 17 слов
#   18 букв: 11 слов
#   19 букв: 11 слов
#   20 букв: 6 слов
#   21 букв: 2 слов
#   22 букв: 3 слов
#   23 букв: 1 слов
#   24 букв: 1 слов
#   25 букв: 3 слов
#   26 букв: 1 слов
#   27 букв: 2 слов
#   28 букв: 2 слов
#   33 букв: 1 слов
#   41 букв: 1 слов
#   51 букв: 1 слов
#   98 букв: 1 слов

# %%
# Статистика по очищенным данным
total_words2 = len(all_cleaned_words2)
total_chars2 = 0
word_lengths2 = []

# Ваш код здесь: создайте список длин слов word_lengths
# и посчитайте общее количество символов total_chars

for word in all_cleaned_words2:
    length = len(word)
    word_lengths2.append(length)
    total_chars2 += length

# Анализ длин слов: допишите код для подсчета количества слов разной длины
word_length_count2 = {}
for length in word_lengths2:
# Ваш код здесь: для каждого значения длины в списке word_lengths
# если длина уже зафиксирована в word_length_count, то выполняем >
    if length in word_length_count2:
        word_length_count2[length] += 1
#                иначе: выполняем >
    else:
        word_length_count2[length] = 1

total_words_after = total_words2
total_chars_after = total_chars2

# Ожидаемый результат:
print(f"Слов после очистки: {total_words_after}")
print(f"Символов после очистки: {total_chars_after}")
print("Распределение длин слов:")
for length in sorted(word_length_count2.keys()):
    print(f"  {length} букв: {word_length_count2[length]} слов")
# Out:
# Слов после очистки: 6900923
# Символов после очистки: 27053968
# Распределение длин слов:
#   2 букв: 1523224 слов
#   3 букв: 1794686 слов
#   4 букв: 1720962 слов
#   5 букв: 773155 слов
#   6 букв: 433234 слов
#   7 букв: 307562 слов
#   8 букв: 165474 слов
#   9 букв: 97057 слов
#   10 букв: 49481 слов
#   11 букв: 19019 слов
#   12 букв: 9536 слов
#   13 букв: 4396 слов
#   14 букв: 1586 слов
#   15 букв: 609 слов
#   16 букв: 301 слов
#   17 букв: 181 слов
#   18 букв: 89 слов
#   19 букв: 250 слов
#   20 букв: 25 слов
#   21 букв: 18 слов
#   22 букв: 10 слов
#   23 букв: 16 слов
#   24 букв: 12 слов
#   25 букв: 9 слов
#   26 букв: 1 слов
#   27 букв: 8 слов
#   28 букв: 2 слов
#   29 букв: 4 слов
#   30 букв: 4 слов
#   33 букв: 3 слов
#   34 букв: 2 слов
#   35 букв: 3 слов
#   38 букв: 1 слов
#   41 букв: 1 слов
#   51 букв: 1 слов
#   98 букв: 1 слов

# %%
# Статистика по очищенным данным
total_words3 = len(all_cleaned_words3)
total_chars3 = 0
word_lengths3 = []

# Ваш код здесь: создайте список длин слов word_lengths
# и посчитайте общее количество символов total_chars

for word in all_cleaned_words3:
    length = len(word)
    word_lengths3.append(length)
    total_chars3 += length

# Анализ длин слов: допишите код для подсчета количества слов разной длины
word_length_count3 = {}
for length in word_lengths3:
# Ваш код здесь: для каждого значения длины в списке word_lengths
# если длина уже зафиксирована в word_length_count, то выполняем >
    if length in word_length_count3:
        word_length_count3[length] += 1
#                иначе: выполняем >
    else:
        word_length_count3[length] = 1

total_words_after = total_words3
total_chars_after = total_chars3

# Ожидаемый результат:
print(f"Слов после очистки: {total_words_after}")
print(f"Символов после очистки: {total_chars_after}")
print("Распределение длин слов:")
for length in sorted(word_length_count3.keys()):
    print(f"  {length} букв: {word_length_count3[length]} слов")
# Out:
# Слов после очистки: 3001928
# Символов после очистки: 12515019
# Распределение длин слов:
#   2 букв: 548263 слов
#   3 букв: 733926 слов
#   4 букв: 746578 слов
#   5 букв: 389932 слов
#   6 букв: 222086 слов
#   7 букв: 160798 слов
#   8 букв: 88989 слов
#   9 букв: 54298 слов
#   10 букв: 30712 слов
#   11 букв: 13457 слов
#   12 букв: 6826 слов
#   13 букв: 3347 слов
#   14 букв: 1390 слов
#   15 букв: 612 слов
#   16 букв: 318 слов
#   17 букв: 134 слов
#   18 букв: 90 слов
#   19 букв: 44 слов
#   20 букв: 29 слов
#   21 букв: 23 слов
#   22 букв: 11 слов
#   23 букв: 16 слов
#   24 букв: 14 слов
#   25 букв: 10 слов
#   26 букв: 1 слов
#   27 букв: 7 слов
#   28 букв: 1 слов
#   29 букв: 4 слов
#   30 букв: 4 слов
#   33 букв: 2 слов
#   34 букв: 2 слов
#   35 букв: 3 слов
#   38 букв: 1 слов

# %%
# Статистика по очищенным данным
total_words4 = len(all_cleaned_words4)
total_chars4 = 0
word_lengths4 = []

# Ваш код здесь: создайте список длин слов word_lengths
# и посчитайте общее количество символов total_chars

for word in all_cleaned_words4:
    length = len(word)
    word_lengths4.append(length)
    total_chars4 += length

# Анализ длин слов: допишите код для подсчета количества слов разной длины
word_length_count4 = {}
for length in word_lengths4:
# Ваш код здесь: для каждого значения длины в списке word_lengths
# если длина уже зафиксирована в word_length_count, то выполняем >
    if length in word_length_count4:
        word_length_count4[length] += 1
#                иначе: выполняем >
    else:
        word_length_count4[length] = 1

total_words_after = total_words4
total_chars_after = total_chars4

# Ожидаемый результат:
print(f"Слов после очистки: {total_words_after}")
print(f"Символов после очистки: {total_chars_after}")
print("Распределение длин слов:")
for length in sorted(word_length_count4.keys()):
    print(f"  {length} букв: {word_length_count4[length]} слов")
# Out:
# Слов после очистки: 3754297
# Символов после очистки: 14543240
# Распределение длин слов:
#   2 букв: 792159 слов
#   3 букв: 989697 слов
#   4 букв: 983781 слов
#   5 букв: 445871 слов
#   6 букв: 243277 слов
#   7 букв: 151412 слов
#   8 букв: 75975 слов
#   9 букв: 42591 слов
#   10 букв: 18823 слов
#   11 букв: 5903 слов
#   12 букв: 3026 слов
#   13 букв: 1138 слов
#   14 букв: 282 слов
#   15 букв: 52 слов
#   16 букв: 19 слов
#   17 букв: 63 слов
#   18 букв: 22 слов
#   19 букв: 205 слов
#   24 букв: 1 слов

# %%
# Статистика по очищенным данным
total_words5 = len(all_cleaned_words5)
total_chars5 = 0
word_lengths5 = []

# Ваш код здесь: создайте список длин слов word_lengths
# и посчитайте общее количество символов total_chars

for word in all_cleaned_words5:
    length = len(word)
    word_lengths5.append(length)
    total_chars5 += length

# Анализ длин слов: допишите код для подсчета количества слов разной длины
word_length_count5 = {}
for length in word_lengths5:
# Ваш код здесь: для каждого значения длины в списке word_lengths
# если длина уже зафиксирована в word_length_count, то выполняем >
    if length in word_length_count5:
        word_length_count5[length] += 1
#                иначе: выполняем >
    else:
        word_length_count5[length] = 1

total_words_after = total_words5
total_chars_after = total_chars5

# Ожидаемый результат:
print(f"Слов после очистки: {total_words_after}")
print(f"Символов после очистки: {total_chars_after}")
print("Распределение длин слов:")
for length in sorted(word_length_count5.keys()):
    print(f"  {length} букв: {word_length_count5[length]} слов")
# Out:
# Слов после очистки: 3524835
# Символов после очистки: 14643162
# Распределение длин слов:
#   2 букв: 666389 слов
#   3 букв: 880968 слов
#   4 букв: 880766 слов
#   5 букв: 425302 слов
#   6 букв: 255069 слов
#   7 букв: 175610 слов
#   8 букв: 102856 слов
#   9 букв: 60865 слов
#   10 букв: 34706 слов
#   11 букв: 16675 слов
#   12 букв: 10611 слов
#   13 букв: 5627 слов
#   14 букв: 3330 слов
#   15 букв: 1970 слов
#   16 букв: 1292 слов
#   17 букв: 668 слов
#   18 букв: 558 слов
#   19 букв: 331 слов
#   20 букв: 262 слов
#   21 букв: 173 слов
#   22 букв: 162 слов
#   23 букв: 94 слов
#   24 букв: 98 слов
#   25 букв: 62 слов
#   26 букв: 45 слов
#   27 букв: 56 слов
#   28 букв: 32 слов
#   29 букв: 28 слов
#   30 букв: 31 слов
#   31 букв: 12 слов
#   32 букв: 34 слов
#   33 букв: 16 слов
#   34 букв: 14 слов
#   35 букв: 18 слов
#   36 букв: 17 слов
#   37 букв: 2 слов
#   38 букв: 3 слов
#   39 букв: 18 слов
#   40 букв: 3 слов
#   41 букв: 2 слов
#   42 букв: 6 слов
#   43 букв: 2 слов
#   44 букв: 3 слов
#   45 букв: 7 слов
#   47 букв: 4 слов
#   48 букв: 4 слов
#   49 букв: 1 слов
#   51 букв: 2 слов
#   53 букв: 1 слов
#   54 букв: 1 слов
#   56 букв: 2 слов
#   57 букв: 1 слов
#   58 букв: 1 слов
#   59 букв: 5 слов
#   60 букв: 7 слов
#   63 букв: 1 слов
#   65 букв: 4 слов
#   66 букв: 1 слов
#   87 букв: 1 слов
#   90 букв: 1 слов
#   104 букв: 1 слов
#   105 букв: 2 слов
#   112 букв: 1 слов
#   114 букв: 1 слов

# %% [markdown]
# Часть 2: частотность слов

# %%
# Считаем частотность слов (по аналогии с подсчетом word_length_count)
word_frequency = {}
# Ваш код здесь:
# проходим по all_cleaned_words
# если слово зафиксировано в word_frequency, то
        word_frequency[word] += 1
# иначе
        word_frequency[word] = 1

# Находим топ-10 самых частых слов
# Начинаем с формирования кортежей вида (частотность слова, лексема)
word_count_pairs = []
for word, count in word_frequency.items():
    word_count_pairs.append((count, word))

# Сортируем вручную через вложенные циклы
for i in range(len(word_count_pairs)):
    for j in range(i + 1, len(word_count_pairs)):
        if word_count_pairs[j][0] > word_count_pairs[i][0]:
            # Меняем местами
            temp = word_count_pairs[i]
            word_count_pairs[i] = word_count_pairs[j]
            word_count_pairs[j] = temp

print("Топ-10 самых частых слов:")
for i in range(min(10, len(word_count_pairs))):
    count, word = word_count_pairs[i]
    print(f"  {i+1}. '{word}': {count} раз")

# Анализ уникальных слов
# Ваш код здесь: создайте множество unique_words

print(f"\nВсего уникальных слов: {len(unique_words)}")
# Out:
# Топ-10 самых частых слов:
#   1. 'the': 2928 раз
#   2. 'to': 2579 раз
#   3. 'you': 2564 раз
#   4. 'it': 2075 раз
#   5. 'and': 1668 раз
#   6. 'that': 1450 раз
#   7. 'my': 1201 раз
#   8. 'in': 1174 раз
#   9. 'is': 1096 раз
#   10. 'of': 1084 раз
#
# Всего уникальных слов: 10765

# %%
word_frequency1 = {}
for word in all_cleaned_words1:
    if word in word_frequency1:
        word_frequency1[word] += 1
    else:
        word_frequency1[word] = 1

word_count_pairs1 = []
for word, count in word_frequency1.items():
    word_count_pairs1.append((count, word))

for i in range(len(word_count_pairs1)):
    for j in range(i + 1, len(word_count_pairs1)):
        if word_count_pairs1[j][0] > word_count_pairs1[i][0]:
            temp = word_count_pairs1[i]
            word_count_pairs1[i] = word_count_pairs1[j]
            word_count_pairs1[j] = temp

print("Топ-10 самых частых слов:")
for i in range(min(10, len(word_count_pairs1))):
    count, word = word_count_pairs1[i]
    print(f"  {i+1}. '{word}': {count} раз")

unique_words1 = set(all_cleaned_words1)
print(f"Всего уникальных слов: {len(unique_words1)}")
print()
# Out:
# Топ-10 самых частых слов:
#   1. 'the': 2918 раз
#   2. 'to': 2578 раз
#   3. 'you': 2308 раз
#   4. 'and': 1658 раз
#   5. 'it': 1472 раз
#   6. 'my': 1197 раз
#   7. 'in': 1169 раз
#   8. 'that': 1167 раз
#   9. 'is': 1090 раз
#   10. 'of': 1084 раз
# Всего уникальных слов: 11259

# %%
word_frequency2 = {}

for word in all_cleaned_words2:
    if word in word_frequency2:
      word_frequency2[word] += 1
    else:
      word_frequency2[word] = 1


word_count_pairs2 = []
for word, count in word_frequency2.items():
    word_count_pairs2.append((count, word))


for i in range(len(word_count_pairs2)):
    for j in range(i + 1, len(word_count_pairs2)):
        if word_count_pairs2[j][0] > word_count_pairs2[i][0]:

            temp = word_count_pairs2[i]
            word_count_pairs2[i] = word_count_pairs2[j]
            word_count_pairs2[j] = temp

print("Топ-10 самых частых слов:")
for i in range(min(10, len(word_count_pairs2))):
    count, word = word_count_pairs2[i]
    print(f"  {i+1}. '{word}': {count} раз")

unique_words2 = set(all_cleaned_words2)
print(f"\nВсего уникальных слов: {len(unique_words2)}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-4067697520.py in <cell line: 0>()
#      19 for i in range(len(word_count_pairs2)):
#      20     for j in range(i + 1, len(word_count_pairs2)):
# ---> 21         if word_count_pairs2[j][0] > word_count_pairs2[i][0]:
#      22             # Меняем местами
#      23             temp = word_count_pairs2[i]
#
# KeyboardInterrupt:

# %%
word_frequency3 = {}
for word in all_cleaned_words3:
    if word in word_frequency3:
        word_frequency3[word] += 1
    else:
        word_frequency3[word] = 1

word_count_pairs3 = []
for word, count in word_frequency3.items():
    word_count_pairs3.append((count, word))

for i in range(len(word_count_pairs3)):
    for j in range(i + 1, len(word_count_pairs3)):
        if word_count_pairs3[j][0] > word_count_pairs3[i][0]:
            temp = word_count_pairs3[i]
            word_count_pairs3[i] = word_count_pairs3[j]
            word_count_pairs3[j] = temp

print("Топ-10 самых частых слов:")
for i in range(min(10, len(word_count_pairs3))):
    count, word = word_count_pairs3[i]
    print(f"  {i+1}. '{word}': {count} раз")

unique_words3 = set(all_cleaned_words3)
print(f"Всего уникальных слов: {len(unique_words3)}")
print()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3672318093.py in <cell line: 0>()
#      12 for i in range(len(word_count_pairs3)):
#      13     for j in range(i + 1, len(word_count_pairs3)):
# ---> 14         if word_count_pairs3[j][0] > word_count_pairs3[i][0]:
#      15             temp = word_count_pairs3[i]
#      16             word_count_pairs3[i] = word_count_pairs3[j]
#
# KeyboardInterrupt:

# %%
word_frequency4 = {}
for word in all_cleaned_words4:
    if word in word_frequency4:
        word_frequency4[word] += 1
    else:
        word_frequency4[word] = 1

word_count_pairs4 = []
for word, count in word_frequency4.items():
    word_count_pairs4.append((count, word))

for i in range(len(word_count_pairs4)):
    for j in range(i + 1, len(word_count_pairs4)):
        if word_count_pairs4[j][0] > word_count_pairs4[i][0]:
            temp = word_count_pairs4[i]
            word_count_pairs4[i] = word_count_pairs4[j]
            word_count_pairs4[j] = temp

print("Топ-10 самых частых слов:")
for i in range(min(10, len(word_count_pairs4))):
    count, word = word_count_pairs4[i]
    print(f"  {i+1}. '{word}': {count} раз")

unique_words4 = set(all_cleaned_words4)
print(f"Всего уникальных слов: {len(unique_words4)}")
print()
# Out:
# Топ-10 самых частых слов:
#   1. 'you': 116813 раз
#   2. 'the': 115660 раз
#   3. 'it': 91854 раз
#   4. 'and': 90807 раз
#   5. 'to': 74145 раз
#   6. 'that': 60496 раз
#   7. 'yeah': 56744 раз
#   8. 'in': 44184 раз
#   9. 'of': 42332 раз
#   10. 'oh': 40782 раз
# Всего уникальных слов: 20781

# %%
word_frequency5 = {}
for word in all_cleaned_words5:
    if word in word_frequency5:
        word_frequency5[word] += 1
    else:
        word_frequency5[word] = 1

word_count_pairs5 = []
for word, count in word_frequency5.items():
    word_count_pairs5.append((count, word))

for i in range(len(word_count_pairs5)):
    for j in range(i + 1, len(word_count_pairs5)):
        if word_count_pairs5[j][0] > word_count_pairs5[i][0]:
            temp = word_count_pairs5[i]
            word_count_pairs5[i] = word_count_pairs5[j]
            word_count_pairs5[j] = temp

print("Топ-10 самых частых слов:")
for i in range(min(10, len(word_count_pairs5))):
    count, word = word_count_pairs5[i]
    print(f"  {i+1}. '{word}': {count} раз")

unique_words5 = set(all_cleaned_words5)
print(f"Всего уникальных слов: {len(unique_words5)}")
print()
